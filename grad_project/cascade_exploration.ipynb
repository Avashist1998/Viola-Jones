# %%
from typing import Final
import imageio.v2 as imageio
import matplotlib.pyplot as plt

from utils.visualization import draw_square

face_file: Final = "../dataset/groupe2.jpg"
image = imageio.imread(face_file)

# %% [markdown]
# ### Test Square drawer function

# %%
plt.imshow(image)
plt.show()

# %%
image_plus_squares = draw_square(image, 75, 70, 100, 105, 5)
image_plus_squares = draw_square(image_plus_squares, 75, 200, 100, 120, 5)
image_plus_squares = draw_square(image_plus_squares, 55, 335, 100, 120, 5)
plt.imshow(image_plus_squares)
plt.show()

# %%
b_w_image = 0.299*image[:,:,0]+0.587*image[:,:,1]+0.114*image[:,:,2]
plt.imshow(b_w_image)
plt.show()

# %%
b_w_image_plus_squares = draw_square(b_w_image, 75, 70, 100, 105, 5)
b_w_image_plus_squares = draw_square(b_w_image_plus_squares, 75, 200, 100, 120, 5)
b_w_image_plus_squares = draw_square(b_w_image_plus_squares, 55, 335, 100, 120, 5)
plt.imshow(b_w_image_plus_squares)
plt.show()

# %% [markdown]
# ### Creating the Classification cascade
